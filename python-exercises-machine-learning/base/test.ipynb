# %%
import numpy as np
import matplotlib.pyplot as plt

# 设定时间范围
t = np.arange(0, 2*np.pi, 0.01)

# 生成正弦波
y = np.sin(t)

# 绘制图形
plt.plot(t, y)
plt.title('sin')
plt.xlabel('time')
plt.ylabel('y')
plt.grid(True)
plt.show()
